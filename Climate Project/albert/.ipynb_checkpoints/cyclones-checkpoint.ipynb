# %% [markdown]
# # Cyclones: Exploratory Analysis

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## South Indian Ocean

# %%
full_si_df = pd.read_csv('./SI_with_ids.csv')
full_si_df
# Out:
#         id Basin  No. of Cycl                 Time     V5  V6    Lat     Lon  \
# 0        1    SI            1  1981-07-25 12:00:00   BEST   0   118S    867E
# 1        1    SI            1  1981-07-25 18:00:00   BEST   0   116S    864E
# 2        1    SI            1  1981-07-26 00:00:00   BEST   0   113S    862E
# 3        1    SI            1  1981-07-26 06:00:00   BEST   0   109S    862E
# 4        1    SI            1  1981-07-26 12:00:00   BEST   0   104S    861E
# ...    ...   ...          ...                  ...    ...  ..    ...     ...
# 20397  660    SI           27  2019-05-17 00:00:00   BEST   0    99S   1340E
# 20398  660    SI           27  2019-05-17 06:00:00   BEST   0    96S   1327E
# 20399  660    SI           27  2019-05-17 12:00:00   BEST   0    88S   1318E
# 20400  660    SI           27  2019-05-17 18:00:00   BEST   0    84S   1308E
# 20401  660    SI           27  2019-05-18 00:00:00   BEST   0    79S   1298E
#
# ...

# %%
# only take a subset of columns for now
relevant_si_df = full_si_df[["id", "Time", "Lat", "Lon", "Speed(knots)"]]
relevant_si_df
# NOTE: why is there a cyclone in July? is this a data error?
# Out:
#         id                 Time    Lat     Lon  Speed(knots)
# 0        1  1981-07-25 12:00:00   118S    867E            20
# 1        1  1981-07-25 18:00:00   116S    864E            25
# 2        1  1981-07-26 00:00:00   113S    862E            25
# 3        1  1981-07-26 06:00:00   109S    862E            25
# 4        1  1981-07-26 12:00:00   104S    861E            25
# ...    ...                  ...    ...     ...           ...
# 20397  660  2019-05-17 00:00:00    99S   1340E            25
# 20398  660  2019-05-17 06:00:00    96S   1327E            20
# 20399  660  2019-05-17 12:00:00    88S   1318E            20
# 20400  660  2019-05-17 18:00:00    84S   1308E            20
# 20401  660  2019-05-18 00:00:00    79S   1298E            15
#
# [20402 rows x 5 columns]

# %% [markdown]
# ###  Has the number of cyclones been increasing in this basin?

# %% [markdown]
# ### Where do cyclones occur primarily?
