# %%
from utils.cyclone_utils import get_datetime
import pandas as pd


## CYCLONE MASTER DF
cyclone_df = pd.read_csv('../cyclone_data/jtwc/cleaned/full_cleaned.csv')
cyclone_df['month'] = cyclone_df['timestamp'].apply(lambda x: get_datetime(x).month) 
cyclone_df
# Out:
#                 timestamp   Storm ID BASIN  Season  SEASON TC NUMBER  \
# 0     1982-03-14 06:00:00   1982-N-1    WP  1982.0               1.0
# 1     1981-10-21 06:00:00   1982-S-2    SI  1982.0               2.0
# 2     1982-03-18 06:00:00   1982-N-2    WP  1982.0               2.0
# 3     1981-11-03 18:00:00   1982-S-3    SI  1982.0               3.0
# 4     1982-03-28 06:00:00   1982-N-3    WP  1982.0               3.0
# ...                   ...        ...   ...     ...               ...
# 1854  2022-10-14 06:00:00  2022-N-24    WP  2022.0              24.0
# 1855  2022-10-26 00:00:00  2022-N-26    WP  2022.0              26.0
# 1856  2022-10-28 12:00:00  2022-N-27    WP  2022.0              27.0
# 1857  2022-11-11 18:00:00  2022-N-28    WP  2022.0              28.0
# 1858  2022-12-08 00:00:00  2022-N-29    WP  2022.0              29.0
#
#       Latitude (degrees)  Longitude (degrees)  VMAX (kt)  Peak VMAX (kt)  \
# 0                    7.1                153.0       15.0            60.0
# 1                   -8.0                 84.6       40.0            85.0
# 2                    3.8                160.7       25.0           105.0
# 3                   -8.6                 92.9       55.0            80.0
# 4                    3.5                156.6       20.0            75.0
# ...                  ...                  ...        ...             ...
# 1854                26.4                154.4       25.0            40.0
# 1855                12.2                133.8       20.0            75.0
# 1856                 8.0                140.4       25.0            40.0
# 1857                20.2                166.3       20.0            40.0
# 1858                 6.4                133.1       15.0            50.0
#
#           ACE  Maximum 24h Intensification  Month  Tropical SST  \
# 0     0.73250                         15.0      3     27.237669
# 1     1.18725                         25.0     10     26.766030
# 2     2.02800                         25.0      3     27.237669
# 3     1.08875                         15.0     11     26.829243
# 4     0.70650                         15.0      3     27.237669
# ...       ...                          ...    ...           ...
# 1854  0.19675                         15.0     10     26.962795
# 1855  0.67825                         25.0     10     26.962795
# 1856  0.10875                         15.0     10     26.962795
# 1857  0.10600                         10.0     11     27.142609
# 1858  0.17550                         20.0     12     27.141811
#
#       Tropical Anomaly  Local SST  Relative SST  Saffir-Simpson Category  \
# 0            -0.270336  28.082220      0.844551                        1
# 1            -0.146004  28.012896      1.246866                        2
# 2            -0.270336  29.003502      1.765833                        3
# 3            -0.228115  27.334639      0.505396                        1
# 4            -0.270336  28.872086      1.634417                        1
# ...                ...        ...           ...                      ...
# 1854          0.050762  28.137896      1.175100                        1
# 1855          0.050762  29.645842      2.683046                        1
# 1856          0.050762  29.821840      2.859045                        1
# 1857          0.085251  28.148760      1.006151                        1
# 1858          0.112261  29.715696      2.573885                        1
#
#       month
# 0         3
# 1        10
# 2         3
# 3        11
# 4         3
# ...     ...
# 1854     10
# 1855     10
# 1856     10
# 1857     11
# 1858     12
#
# [1859 rows x 18 columns]

# %%
## Split into basins and calculate rates for each calendar month
dfs = {}
for basin_name in cyclone_df['BASIN'].unique():
    dfs[basin_name] = cyclone_df.loc[cyclone_df.loc[:, 'BASIN'] == basin_name]

## rate = mean occurrence per month....
rates = {}
basin_boundaries = {}

for basin_name in dfs.keys():
    basin_df = dfs[basin_name]
    BASIN_NUM_SEASONS = basin_df['Season'].max() - basin_df['Season'].min()
    # basin_boundaries[basin_name] = {
    #     'lat': {
    #         'min': basin_df['Latitude (degrees)'].min(),
    #         'max': basin_df['Latitude (degrees)'].max()
    #     },
    #     'lon': {
    #         'min': basin_df['Longitude (degrees)'].min(),
    #         'max': basin_df['Longitude (degrees)'].max()
    #     }
    # }

    for month in range(1,13):
        ## probably faster with groupby
        basin_month_num_cyclones = basin_df.loc[basin_df.loc[:, 'month'] == month].shape[0]
        avg_month_rate = basin_month_num_cyclones/BASIN_NUM_SEASONS
        if basin_name not in rates.keys():
            rates[basin_name] = {}
        rates[basin_name][month] = avg_month_rate

# %%
from datetime import datetime, timedelta
import numpy as np


def get_start_of_next_month(dt):
    month = dt.month
    year = dt.year
    if month == 12:
        return datetime.strptime(f'{year + 1}-01-01', "%Y-%m-%d")
    
    return datetime.strptime(f'{year}-{month + 1}-01', "%Y-%m-%d")

new_cyclones = None

for basin_name in rates.keys():
    start_time = None;
    end_time = None
    basin_df = dfs[basin_name]

    if basin_name == 'WP':
        ## should we only filter by cyclone seasons
        start_time = datetime.strptime("2015-01-01", "%Y-%m-%d")
        end_time = datetime.strptime("2050-01-01", "%Y-%m-%d")
    else:
        start_time = datetime.strptime("2015-01-01", "%Y-%m-%d")
        end_time = datetime.strptime("2050-01-01", "%Y-%m-%d")

    current_time = start_time
   
    while current_time < end_time:
        current_month = current_time.month
        current_year = current_time.year
        start_of_next_month = get_start_of_next_month(current_time)
        print('current time: ' + current_time.strftime('%Y-%m-%d'))
        current_rate = rates[basin_name][current_month]
        if current_rate == 0:
            current_time = get_start_of_next_month(current_time)
            print('no cyclones, skipping month')
        else:
            months_till_cyclone = np.random.exponential(1/current_rate)
            print(f'months till next cyclone: {months_till_cyclone}')
            delta = timedelta(days = months_till_cyclone * (365.25/12))
            time_of_start = current_time + delta
            if time_of_start > start_of_next_month:
                print('in next month, rate changes!!!')
                current_time = get_start_of_next_month(current_time)
            else:
                print('still in current month')
                time_of_start = current_time + delta
                print('genesis date: ' +  time_of_start.strftime('%Y-%m-%d'))

                ## SAMPLE ITS LOCATION AND ADD TO DATAFRAME
                ## ATM JUST UNIFORMLY...

                ## add some gaussian noise....
                # lat_noise = np.random.normal(0,1)
                # lon_noise = np.random.normal(0,2)

                coord_pairs = np.array(list(zip(basin_df['Latitude (degrees)'], basin_df['Longitude (degrees)'])))
                index = np.random.choice(coord_pairs.shape[0], 1)
                coord = coord_pairs[index][0]

                lat = coord[0]
                lon = coord[1]

                cyclone_obj = {
                    'timestamp': [datetime.strftime(time_of_start, '%Y-%m-%d')],
                    'lat': [lat],
                    'lon': [lon],
                    'BASIN': [basin_name]
                }

                print(cyclone_obj)

                new_cyclone = pd.DataFrame(cyclone_obj)
                if new_cyclones is None:
                    new_cyclones = new_cyclone
                else:
                    new_cyclones = pd.concat([new_cyclones, new_cyclone])

                # current_time += delta
                current_time = time_of_start
        

new_cyclones =  new_cyclones.sort_values(by=['timestamp'])
new_cyclones['index'] = range(new_cyclones.shape[0])
new_cyclones = new_cyclones.set_index('index')
# Out:
# current time: 2015-01-01
# months till next cyclone: 2.844157637392994
# in next month, rate changes!!!
# current time: 2015-02-01
# months till next cyclone: 2.9717247466203482
# in next month, rate changes!!!
# current time: 2015-03-01
# months till next cyclone: 3.803030930693165
# in next month, rate changes!!!
# current time: 2015-04-01
# months till next cyclone: 1.819519526183259
# in next month, rate changes!!!
# current time: 2015-05-01
# months till next cyclone: 1.3994842463891635
# in next month, rate changes!!!
# current time: 2015-06-01
# months till next cyclone: 0.42706884712456894
# still in current month
# genesis date: 2015-06-13
# {'timestamp': ['2015-06-13'], 'lat': [3.1], 'lon': [179.0], 'BASIN': ['WP']}
# current time: 2015-06-13
# months till next cyclone: 0.2346030085664571
# still in current month
# genesis date: 2015-06-21
# {'timestamp': ['2015-06-21'], 'lat': [19.4], 'lon': [124.8], 'BASIN': ['WP']}
# current time: 2015-06-21
# months till next cyclone: 1.4469838305801617
# in next month, rate changes!!!
# current time: 2015-07-01
# months till next cyclone: 0.03956135301378204
# still in current month
# genesis date: 2015-07-02
# {'timestamp': ['2015-07-02'], 'lat': [17.4], 'lon': [123.5], 'BASIN': ['WP']}
# current time: 2015-07-02
# months till next cyclone: 0.10538855383612303
# still in current month
# genesis date: 2015-07-05
# {'timestamp': ['2015-07-05'], 'lat': [18.3], 'lon': [139.8], 'BASIN': ['WP']}
# current time: 2015-07-05
# months till next cyclone: 0.06387187122237793
# still in current month
# genesis date: 2015-07-07
# {'timestamp': ['2015-07-07'], 'lat': [4.2], 'lon': [148.3], 'BASIN': ['WP']}
# current time: 2015-07-07
# months till next cyclone: 0.15203148964523613
# still in current month
# genesis date: 2015-07-11
# {'timestamp': ['2015-07-11'], 'lat': [20.1], 'lon': [138.0], 'BASIN': ['WP']}
# current time: 2015-07-11
# months till next cyclone: 0.5183406175686863
# still in current month
# genesis date: 2015-07-27
# {'timestamp': ['2015-07-27'], 'lat': [19.0], 'lon': [137.8], 'BASIN': ['WP']}
# current time: 2015-07-27
# months till next cyclone: 0.00785779614474444
# still in current month
# genesis date: 2015-07-27
# {'timestamp': ['2015-07-27'], 'lat': [15.4], 'lon': [112.9], 'BASIN': ['WP']}
# current time: 2015-07-27
# months till next cyclone: 0.19760011233376606
# in next month, rate changes!!!
# current time: 2015-08-01
# months till next cyclone: 0.7575734014122264
# still in current month
# genesis date: 2015-08-24
# {'timestamp': ['2015-08-24'], 'lat': [7.6], 'lon': [176.7], 'BASIN': ['WP']}
# current time: 2015-08-24
# months till next cyclone: 0.05332366372922423
# still in current month
# genesis date: 2015-08-25
# {'timestamp': ['2015-08-25'], 'lat': [17.0], 'lon': [141.7], 'BASIN': ['WP']}
# current time: 2015-08-25
# months till next cyclone: 0.07213608410336833
# still in current month
# genesis date: 2015-08-27
# {'timestamp': ['2015-08-27'], 'lat': [18.7], 'lon': [143.8], 'BASIN': ['WP']}
# current time: 2015-08-27
# months till next cyclone: 0.004383929406547237
# still in current month
# genesis date: 2015-08-28
# {'timestamp': ['2015-08-28'], 'lat': [6.6], 'lon': [173.3], 'BASIN': ['WP']}
# current time: 2015-08-28
# months till next cyclone: 0.0007674404736355906
# still in current month
# genesis date: 2015-08-28
# {'timestamp': ['2015-08-28'], 'lat': [10.6], 'lon': [118.2], 'BASIN': ['WP']}
# current time: 2015-08-28
# months till next cyclone: 0.08233389462113298
# still in current month
# genesis date: 2015-08-30
# {'timestamp': ['2015-08-30'], 'lat': [9.2], 'lon': [140.0], 'BASIN': ['WP']}
# current time: 2015-08-30
# months till next cyclone: 0.28107805856397616
# in next month, rate changes!!!
# current time: 2015-09-01
# months till next cyclone: 0.41585298837431295
# still in current month
# genesis date: 2015-09-13
# {'timestamp': ['2015-09-13'], 'lat': [18.7], 'lon': [139.3], 'BASIN': ['WP']}
# current time: 2015-09-13
# months till next cyclone: 0.11949702824276348
# still in current month
# genesis date: 2015-09-17
# {'timestamp': ['2015-09-17'], 'lat': [17.0], 'lon': [149.6], 'BASIN': ['WP']}
# current time: 2015-09-17
# months till next cyclone: 0.058781468173597036
# still in current month
# genesis date: 2015-09-19
# {'timestamp': ['2015-09-19'], 'lat': [19.0], 'lon': [129.4], 'BASIN': ['WP']}
# current time: 2015-09-19
# months till next cyclone: 0.060023232883706895
# still in current month
# genesis date: 2015-09-20
# {'timestamp': ['2015-09-20'], 'lat': [4.7], 'lon': [155.1], 'BASIN': ['WP']}
# current time: 2015-09-20
# months till next cyclone: 0.12775466585645856
# still in current month
# genesis date: 2015-09-24
# {'timestamp': ['2015-09-24'], 'lat': [12.1], 'lon': [150.9], 'BASIN': ['WP']}
# current time: 2015-09-24
# months till next cyclone: 0.07095163803639996
# still in current month
# genesis date: 2015-09-26
# {'timestamp': ['2015-09-26'], 'lat': [15.3], 'lon': [123.3], 'BASIN': ['WP']}
# current time: 2015-09-26
# months till next cyclone: 0.10859097882609928
# still in current month
# genesis date: 2015-09-30
# {'timestamp': ['2015-09-30'], 'lat': [7.8], 'lon': [132.4], 'BASIN': ['WP']}
# current time: 2015-09-30
# months till next cyclone: 0.09930437518849032
# in next month, rate changes!!!
# current time: 2015-10-01
# months till next cyclone: 0.2373554196965055
# still in current month
# genesis date: 2015-10-08
# {'timestamp': ['2015-10-08'], 'lat': [12.8], 'lon': [167.7], 'BASIN': ['WP']}
# current time: 2015-10-08
# months till next cyclone: 0.02392842888889191
# still in current month
# genesis date: 2015-10-08
# {'timestamp': ['2015-10-08'], 'lat': [21.1], 'lon': [152.5], 'BASIN': ['WP']}
# current time: 2015-10-08
# months till next cyclone: 0.01522396953200812
# still in current month
# genesis date: 2015-10-09
# {'timestamp': ['2015-10-09'], 'lat': [5.1], 'lon': [168.0], 'BASIN': ['WP']}
# current time: 2015-10-09
# months till next cyclone: 0.3019371564834963
# still in current month
# genesis date: 2015-10-18
# {'timestamp': ['2015-10-18'], 'lat': [21.9], 'lon': [154.9], 'BASIN': ['WP']}
# current time: 2015-10-18
# months till next cyclone: 0.4521613330642412
# in next month, rate changes!!!
# current time: 2015-11-01
# months till next cyclone: 0.28854677275995994
# still in current month
# genesis date: 2015-11-09
# {'timestamp': ['2015-11-09'], 'lat': [18.8], 'lon': [145.7], 'BASIN': ['WP']}
# current time: 2015-11-09
# months till next cyclone: 0.20568788783353123
# still in current month
# genesis date: 2015-11-16
# {'timestamp': ['2015-11-16'], 'lat': [5.0], 'lon': [140.7], 'BASIN': ['WP']}
# current time: 2015-11-16
# months till next cyclone: 0.1286709657676567
# still in current month
# genesis date: 2015-11-19
# {'timestamp': ['2015-11-19'], 'lat': [16.6], 'lon': [137.4], 'BASIN': ['WP']}
# current time: 2015-11-19
# months till next cyclone: 0.5803365294547993
# in next month, rate changes!!!
# current time: 2015-12-01
# months till next cyclone: 0.3796407121218415
# still in current month
# genesis date: 2015-12-12
# {'timestamp': ['2015-12-12'], 'lat': [18.4], 'lon': [141.1], 'BASIN': ['WP']}
# current time: 2015-12-12
# months till next cyclone: 0.17466978763180302
# still in current month
# genesis date: 2015-12-17
# {'timestamp': ['2015-12-17'], 'lat': [8.6], 'lon': [166.9], 'BASIN': ['WP']}
# current time: 2015-12-17
# months till next cyclone: 0.9470864821381646
# in next month, rate changes!!!
# current time: 2016-01-01
# months till next cyclone: 2.85581468028652
# in next month, rate changes!!!
# current time: 2016-02-01
# months till next cyclone: 8.738283082991886
# in next month, rate changes!!!
# current time: 2016-03-01
# months till next cyclone: 2.195479325336598
# in next month, rate changes!!!
# current time: 2016-04-01
# months till next cyclone: 0.45023229965375416
# still in current month
# genesis date: 2016-04-14
# {'timestamp': ['2016-04-14'], 'lat': [16.1], 'lon': [138.2], 'BASIN': ['WP']}
# current time: 2016-04-14
# months till next cyclone: 2.200754579063777
# in next month, rate changes!!!
# current time: 2016-05-01
# months till next cyclone: 1.2123634626003736
# in next month, rate changes!!!
# current time: 2016-06-01
# months till next cyclone: 0.5304646527338506
# still in current month
# genesis date: 2016-06-17
# {'timestamp': ['2016-06-17'], 'lat': [21.6], 'lon': [118.3], 'BASIN': ['WP']}
# current time: 2016-06-17
# months till next cyclone: 1.9147221278185518
# in next month, rate changes!!!
# current time: 2016-07-01
# months till next cyclone: 0.0235412662162949
# still in current month
# genesis date: 2016-07-01
# {'timestamp': ['2016-07-01'], 'lat': [25.0], 'lon': [160.2], 'BASIN': ['WP']}
# current time: 2016-07-01
# months till next cyclone: 0.15348648191578956
# still in current month
# genesis date: 2016-07-06
# {'timestamp': ['2016-07-06'], 'lat': [13.8], 'lon': [114.5], 'BASIN': ['WP']}
# current time: 2016-07-06
# months till next cyclone: 0.020885588263536686
# still in current month
# genesis date: 2016-07-07
# {'timestamp': ['2016-07-07'], 'lat': [21.4], 'lon': [167.6], 'BASIN': ['WP']}
# current time: 2016-07-07
# months till next cyclone: 0.26501186924418646
# still in current month
# genesis date: 2016-07-15
# {'timestamp': ['2016-07-15'], 'lat': [15.4], 'lon': [112.2], 'BASIN': ['WP']}
# current time: 2016-07-15
# months till next cyclone: 0.6456955180929536
# in next month, rate changes!!!
# current time: 2016-08-01
# months till next cyclone: 0.002791651351113988
# still in current month
# genesis date: 2016-08-01
# {'timestamp': ['2016-08-01'], 'lat': [14.6], 'lon': [127.3], 'BASIN': ['WP']}
# current time: 2016-08-01
# months till next cyclone: 0.07951582840796102
# still in current month
# genesis date: 2016-08-03
# {'timestamp': ['2016-08-03'], 'lat': [7.1], 'lon': [103.7], 'BASIN': ['WP']}
# current time: 2016-08-03
# months till next cyclone: 0.19781181566023182
# still in current month
# genesis date: 2016-08-09
# {'timestamp': ['2016-08-09'], 'lat': [8.2], 'lon': [146.0], 'BASIN': ['WP']}
# current time: 2016-08-09
# months till next cyclone: 0.448284795378961
# still in current month
# genesis date: 2016-08-23
# {'timestamp': ['2016-08-23'], 'lat': [11.8], 'lon': [141.7], 'BASIN': ['WP']}
# current time: 2016-08-23
# months till next cyclone: 0.27487503326262286
# still in current month
# genesis date: 2016-08-31
# {'timestamp': ['2016-08-31'], 'lat': [19.1], 'lon': [112.3], 'BASIN': ['WP']}
# current time: 2016-08-31
# months till next cyclone: 1.1817127966092345
# in next month, rate changes!!!
# current time: 2016-09-01
# months till next cyclone: 0.03320006568423891
# still in current month
# genesis date: 2016-09-02
# {'timestamp': ['2016-09-02'], 'lat': [7.7], 'lon': [153.9], 'BASIN': ['WP']}
# current time: 2016-09-02
# months till next cyclone: 0.17612622233000913
# still in current month
# genesis date: 2016-09-07
# {'timestamp': ['2016-09-07'], 'lat': [24.6], 'lon': [152.3], 'BASIN': ['WP']}
# current time: 2016-09-07
# months till next cyclone: 0.48813022985876836
# still in current month
# genesis date: 2016-09-22
# {'timestamp': ['2016-09-22'], 'lat': [24.0], 'lon': [162.3], 'BASIN': ['WP']}
# current time: 2016-09-22
# months till next cyclone: 0.21484501261969174
# still in current month
# genesis date: 2016-09-28
# {'timestamp': ['2016-09-28'], 'lat': [19.5], 'lon': [124.0], 'BASIN': ['WP']}
# current time: 2016-09-28
# months till next cyclone: 0.1836986861045338
# in next month, rate changes!!!
# current time: 2016-10-01
# months till next cyclone: 0.003986479172955374
# still in current month
# genesis date: 2016-10-01
# {'timestamp': ['2016-10-01'], 'lat': [8.1], 'lon': [140.9], 'BASIN': ['WP']}
# current time: 2016-10-01
# months till next cyclone: 0.24399468662611876
# still in current month
# genesis date: 2016-10-08
# {'timestamp': ['2016-10-08'], 'lat': [21.4], 'lon': [150.3], 'BASIN': ['WP']}
# current time: 2016-10-08
# months till next cyclone: 0.19212471184513405
# still in current month
# genesis date: 2016-10-14
# {'timestamp': ['2016-10-14'], 'lat': [4.5], 'lon': [157.6], 'BASIN': ['WP']}
# current time: 2016-10-14
# months till next cyclone: 0.22851165203548734
# still in current month
# genesis date: 2016-10-21
# {'timestamp': ['2016-10-21'], 'lat': [6.0], 'lon': [140.9], 'BASIN': ['WP']}
# current time: 2016-10-21
# months till next cyclone: 0.6126938604229666
# in next month, rate changes!!!
# current time: 2016-11-01
# months till next cyclone: 0.09602379557273957
# still in current month
# genesis date: 2016-11-03
# {'timestamp': ['2016-11-03'], 'lat': [14.6], 'lon': [126.2], 'BASIN': ['WP']}
# current time: 2016-11-03
# months till next cyclone: 0.6096736850048323
# still in current month
# genesis date: 2016-11-22
# {'timestamp': ['2016-11-22'], 'lat': [18.0], 'lon': [123.1], 'BASIN': ['WP']}
# current time: 2016-11-22
# months till next cyclone: 0.2974146272789444
# in next month, rate changes!!!
# current time: 2016-12-01
# months till next cyclone: 1.0335044443320769
# in next month, rate changes!!!
# current time: 2017-01-01
# months till next cyclone: 1.2733947290338052
# in next month, rate changes!!!
# current time: 2017-02-01
# months till next cyclone: 0.15029438905079662
# still in current month
# genesis date: 2017-02-05
# {'timestamp': ['2017-02-05'], 'lat': [13.4], 'lon': [146.4], 'BASIN': ['WP']}
# current time: 2017-02-05
# months till next cyclone: 5.390637237685664
# in next month, rate changes!!!
# current time: 2017-03-01
# months till next cyclone: 0.01429204957942069
# still in current month
# genesis date: 2017-03-01
# {'timestamp': ['2017-03-01'], 'lat': [13.8], 'lon': [114.5], 'BASIN': ['WP']}
# current time: 2017-03-01
# months till next cyclone: 3.4001644663626154
# in next month, rate changes!!!
# current time: 2017-04-01
# months till next cyclone: 4.117595990802847
# in next month, rate changes!!!
# current time: 2017-05-01
# months till next cyclone: 0.8160665699117099
# still in current month
# genesis date: 2017-05-25
# {'timestamp': ['2017-05-25'], 'lat': [14.9], 'lon': [140.7], 'BASIN': ['WP']}
# current time: 2017-05-25
# months till next cyclone: 1.6555050329622971
# in next month, rate changes!!!
# current time: 2017-06-01
# months till next cyclone: 0.02863431523123679
# still in current month
# genesis date: 2017-06-01
# {'timestamp': ['2017-06-01'], 'lat': [14.6], 'lon': [152.4], 'BASIN': ['WP']}
# current time: 2017-06-01
# months till next cyclone: 0.15527786595429144
# still in current month
# genesis date: 2017-06-06
# {'timestamp': ['2017-06-06'], 'lat': [12.0], 'lon': [142.4], 'BASIN': ['WP']}
# current time: 2017-06-06
# months till next cyclone: 0.06234159258829456
# still in current month
# genesis date: 2017-06-08
# {'timestamp': ['2017-06-08'], 'lat': [5.4], 'lon': [138.6], 'BASIN': ['WP']}
# current time: 2017-06-08
# months till next cyclone: 0.6523627581003926
# still in current month
# genesis date: 2017-06-28
# {'timestamp': ['2017-06-28'], 'lat': [11.8], 'lon': [141.7], 'BASIN': ['WP']}
# current time: 2017-06-28
# months till next cyclone: 0.41358144655558526
# in next month, rate changes!!!
# current time: 2017-07-01
# months till next cyclone: 0.0930869591431732
# still in current month
# genesis date: 2017-07-03
# {'timestamp': ['2017-07-03'], 'lat': [7.8], 'lon': [132.4], 'BASIN': ['WP']}
# current time: 2017-07-03
# months till next cyclone: 0.7403688644169999
# still in current month
# genesis date: 2017-07-26
# {'timestamp': ['2017-07-26'], 'lat': [21.8], 'lon': [129.0], 'BASIN': ['WP']}
# current time: 2017-07-26
# months till next cyclone: 0.2437591104482484
# in next month, rate changes!!!
# current time: 2017-08-01
# months till next cyclone: 0.02683440428255061
# still in current month
# genesis date: 2017-08-01
# {'timestamp': ['2017-08-01'], 'lat': [22.7], 'lon': [131.3], 'BASIN': ['WP']}
# current time: 2017-08-01
# months till next cyclone: 0.011671284183162994
# still in current month
# genesis date: 2017-08-02
# {'timestamp': ['2017-08-02'], 'lat': [15.9], 'lon': [126.9], 'BASIN': ['WP']}
# current time: 2017-08-02
# months till next cyclone: 0.1661030999759384
# still in current month
# genesis date: 2017-08-07
# {'timestamp': ['2017-08-07'], 'lat': [6.5], 'lon': [151.9], 'BASIN': ['WP']}
# current time: 2017-08-07
# months till next cyclone: 0.2385337615056674
# still in current month
# genesis date: 2017-08-14
# {'timestamp': ['2017-08-14'], 'lat': [5.0], 'lon': [155.4], 'BASIN': ['WP']}
# current time: 2017-08-14
# months till next cyclone: 0.22960681167348299
# still in current month
# genesis date: 2017-08-21
# {'timestamp': ['2017-08-21'], 'lat': [19.0], 'lon': [130.0], 'BASIN': ['WP']}
# current time: 2017-08-21
# months till next cyclone: 0.2858256819539497
# still in current month
# genesis date: 2017-08-30
# {'timestamp': ['2017-08-30'], 'lat': [5.0], 'lon': [139.1], 'BASIN': ['WP']}
# current time: 2017-08-30
# months till next cyclone: 0.17716307020267577
# in next month, rate changes!!!
# current time: 2017-09-01
# months till next cyclone: 0.16031149339044354
# still in current month
# genesis date: 2017-09-05
# {'timestamp': ['2017-09-05'], 'lat': [19.4], 'lon': [146.0], 'BASIN': ['WP']}
# current time: 2017-09-05
# months till next cyclone: 0.16331976825766664
# still in current month
# genesis date: 2017-09-10
# {'timestamp': ['2017-09-10'], 'lat': [12.9], 'lon': [117.1], 'BASIN': ['WP']}
# current time: 2017-09-10
# months till next cyclone: 0.11094959087636631
# still in current month
# genesis date: 2017-09-14
# {'timestamp': ['2017-09-14'], 'lat': [16.9], 'lon': [112.3], 'BASIN': ['WP']}
# current time: 2017-09-14
# months till next cyclone: 0.3259844589042497
# still in current month
# genesis date: 2017-09-24
# {'timestamp': ['2017-09-24'], 'lat': [12.4], 'lon': [146.1], 'BASIN': ['WP']}
# current time: 2017-09-24
# months till next cyclone: 0.7712360344398973
# in next month, rate changes!!!
# current time: 2017-10-01
# months till next cyclone: 0.324026253285089
# still in current month
# genesis date: 2017-10-10
# {'timestamp': ['2017-10-10'], 'lat': [8.9], 'lon': [140.7], 'BASIN': ['WP']}
# current time: 2017-10-10
# months till next cyclone: 0.24957920827424862
# still in current month
# genesis date: 2017-10-18
# {'timestamp': ['2017-10-18'], 'lat': [12.1], 'lon': [150.9], 'BASIN': ['WP']}
# current time: 2017-10-18
# months till next cyclone: 0.45979451348214867
# in next month, rate changes!!!
# current time: 2017-11-01
# months till next cyclone: 0.014317657656982185
# still in current month
# genesis date: 2017-11-01
# {'timestamp': ['2017-11-01'], 'lat': [3.6], 'lon': [150.0], 'BASIN': ['WP']}
# current time: 2017-11-01
# months till next cyclone: 0.07634216553846197
# still in current month
# genesis date: 2017-11-03
# {'timestamp': ['2017-11-03'], 'lat': [8.3], 'lon': [144.4], 'BASIN': ['WP']}
# current time: 2017-11-03
# months till next cyclone: 0.19964122779626653
# still in current month
# genesis date: 2017-11-09
# {'timestamp': ['2017-11-09'], 'lat': [18.7], 'lon': [160.2], 'BASIN': ['WP']}
# current time: 2017-11-09
# months till next cyclone: 0.5590454503601968
# still in current month
# genesis date: 2017-11-26
# {'timestamp': ['2017-11-26'], 'lat': [17.8], 'lon': [131.0], 'BASIN': ['WP']}
# current time: 2017-11-26
# months till next cyclone: 1.1788229273152442
# in next month, rate changes!!!
# current time: 2017-12-01
# months till next cyclone: 0.20116254647204512
# still in current month
# genesis date: 2017-12-07
# {'timestamp': ['2017-12-07'], 'lat': [14.0], 'lon': [137.0], 'BASIN': ['WP']}
# current time: 2017-12-07
# months till next cyclone: 0.11093096590510966
# still in current month
# genesis date: 2017-12-10
# {'timestamp': ['2017-12-10'], 'lat': [14.4], 'lon': [115.2], 'BASIN': ['WP']}
# current time: 2017-12-10
# months till next cyclone: 2.3368105978475056
# in next month, rate changes!!!
# current time: 2018-01-01
# months till next cyclone: 1.5801516648924228
# in next month, rate changes!!!
# current time: 2018-02-01
# months till next cyclone: 3.303790501286242
# in next month, rate changes!!!
# current time: 2018-03-01
# months till next cyclone: 0.9501486136192592
# still in current month
# genesis date: 2018-03-29
# {'timestamp': ['2018-03-29'], 'lat': [25.2], 'lon': [124.4], 'BASIN': ['WP']}
# current time: 2018-03-29
# months till next cyclone: 3.2511577863563383
# in next month, rate changes!!!
# current time: 2018-04-01
# months till next cyclone: 0.021274777646293135
# still in current month
# genesis date: 2018-04-01
# {'timestamp': ['2018-04-01'], 'lat': [15.4], 'lon': [112.9], 'BASIN': ['WP']}
# current time: 2018-04-01
# months till next cyclone: 5.023100865887497
# in next month, rate changes!!!
# current time: 2018-05-01
# months till next cyclone: 0.16402571807806768
# still in current month
# genesis date: 2018-05-05
# {'timestamp': ['2018-05-05'], 'lat': [15.1], 'lon': [162.4], 'BASIN': ['WP']}
# current time: 2018-05-05
# months till next cyclone: 0.3024598520343003
# still in current month
# genesis date: 2018-05-15
# {'timestamp': ['2018-05-15'], 'lat': [22.0], 'lon': [184.4], 'BASIN': ['WP']}
# current time: 2018-05-15
# months till next cyclone: 0.3762450902913911
# still in current month
# genesis date: 2018-05-26
# {'timestamp': ['2018-05-26'], 'lat': [7.4], 'lon': [135.0], 'BASIN': ['WP']}
# current time: 2018-05-26
# months till next cyclone: 1.0608771701543491
# in next month, rate changes!!!
# current time: 2018-06-01
# months till next cyclone: 2.0894386008308685
# in next month, rate changes!!!
# current time: 2018-07-01
# months till next cyclone: 0.2770414975178145
# still in current month
# genesis date: 2018-07-09
# {'timestamp': ['2018-07-09'], 'lat': [12.3], 'lon': [141.1], 'BASIN': ['WP']}
# current time: 2018-07-09
# months till next cyclone: 0.23246007827287604
# still in current month
# genesis date: 2018-07-16
# {'timestamp': ['2018-07-16'], 'lat': [8.5], 'lon': [144.0], 'BASIN': ['WP']}
# current time: 2018-07-16
# months till next cyclone: 0.5985337496420808
# in next month, rate changes!!!
# current time: 2018-08-01
# months till next cyclone: 0.2308028834292644
# still in current month
# genesis date: 2018-08-08
# {'timestamp': ['2018-08-08'], 'lat': [15.7], 'lon': [139.7], 'BASIN': ['WP']}
# current time: 2018-08-08
# months till next cyclone: 0.0005706391986505982
# still in current month
# genesis date: 2018-08-08
# {'timestamp': ['2018-08-08'], 'lat': [8.3], 'lon': [145.3], 'BASIN': ['WP']}
# current time: 2018-08-08
# months till next cyclone: 0.018224883025789056
# still in current month
# genesis date: 2018-08-08
# {'timestamp': ['2018-08-08'], 'lat': [9.9], 'lon': [171.1], 'BASIN': ['WP']}
# current time: 2018-08-08
# months till next cyclone: 0.21634685511709578
# still in current month
# genesis date: 2018-08-15
# {'timestamp': ['2018-08-15'], 'lat': [17.5], 'lon': [141.4], 'BASIN': ['WP']}
# current time: 2018-08-15
# months till next cyclone: 0.28884234136487646
# still in current month
# genesis date: 2018-08-23
# {'timestamp': ['2018-08-23'], 'lat': [14.4], 'lon': [123.9], 'BASIN': ['WP']}
# current time: 2018-08-23
# months till next cyclone: 0.051744577641754615
# still in current month
# genesis date: 2018-08-25
# {'timestamp': ['2018-08-25'], 'lat': [14.5], 'lon': [139.6], 'BASIN': ['WP']}
# current time: 2018-08-25
# months till next cyclone: 0.09832196259276778
# still in current month
# genesis date: 2018-08-28
# {'timestamp': ['2018-08-28'], 'lat': [16.9], 'lon': [115.0], 'BASIN': ['WP']}
# current time: 2018-08-28
# months till next cyclone: 0.12696718447333313
# in next month, rate changes!!!
# current time: 2018-09-01
# months till next cyclone: 0.060362383547730096
# still in current month
# genesis date: 2018-09-02
# {'timestamp': ['2018-09-02'], 'lat': [5.0], 'lon': [140.7], 'BASIN': ['WP']}
# current time: 2018-09-02
# months till next cyclone: 0.07305375360531502
# still in current month
# genesis date: 2018-09-05
# {'timestamp': ['2018-09-05'], 'lat': [15.9], 'lon': [131.1], 'BASIN': ['WP']}
# current time: 2018-09-05
# months till next cyclone: 0.038397630388193146
# still in current month
# genesis date: 2018-09-06
# {'timestamp': ['2018-09-06'], 'lat': [17.1], 'lon': [118.6], 'BASIN': ['WP']}
# current time: 2018-09-06
# months till next cyclone: 0.019253707131391306
# still in current month
# genesis date: 2018-09-06
# {'timestamp': ['2018-09-06'], 'lat': [9.8], 'lon': [130.4], 'BASIN': ['WP']}
# current time: 2018-09-06
# months till next cyclone: 0.2644282212353168
# still in current month
# genesis date: 2018-09-14
# {'timestamp': ['2018-09-14'], 'lat': [9.6], 'lon': [153.5], 'BASIN': ['WP']}
# current time: 2018-09-14
# months till next cyclone: 0.19621996387653032
# still in current month
# genesis date: 2018-09-20
# {'timestamp': ['2018-09-20'], 'lat': [9.4], 'lon': [115.6], 'BASIN': ['WP']}
# current time: 2018-09-20
# months till next cyclone: 0.3521313318001495
# in next month, rate changes!!!
# current time: 2018-10-01
# months till next cyclone: 0.4145707062084303
# still in current month
# genesis date: 2018-10-13
# {'timestamp': ['2018-10-13'], 'lat': [15.3], 'lon': [152.4], 'BASIN': ['WP']}
# current time: 2018-10-13
# months till next cyclone: 1.007854193642495
# in next month, rate changes!!!
# current time: 2018-11-01
# months till next cyclone: 0.7837487573479435
# still in current month
# genesis date: 2018-11-24
# {'timestamp': ['2018-11-24'], 'lat': [14.4], 'lon': [123.9], 'BASIN': ['WP']}
# current time: 2018-11-24
# months till next cyclone: 0.028600408074340954
# still in current month
# genesis date: 2018-11-25
# {'timestamp': ['2018-11-25'], 'lat': [15.4], 'lon': [133.8], 'BASIN': ['WP']}
# current time: 2018-11-25
# months till next cyclone: 0.8032904932684962
# in next month, rate changes!!!
# current time: 2018-12-01
# months till next cyclone: 1.9057529555983796
# in next month, rate changes!!!
# current time: 2019-01-01
# months till next cyclone: 1.4999538090051592
# in next month, rate changes!!!
# current time: 2019-02-01
# months till next cyclone: 8.671567247024386
# in next month, rate changes!!!
# current time: 2019-03-01
# months till next cyclone: 0.8211962418075901
# still in current month
# genesis date: 2019-03-25
# {'timestamp': ['2019-03-25'], 'lat': [16.9], 'lon': [115.0], 'BASIN': ['WP']}
# current time: 2019-03-25
# months till next cyclone: 1.3422457477270417
# in next month, rate changes!!!
# current time: 2019-04-01
# months till next cyclone: 3.3370468901667176
# in next month, rate changes!!!
# current time: 2019-05-01
# months till next cyclone: 1.863102000682753
# in next month, rate changes!!!
# current time: 2019-06-01
# months till next cyclone: 1.0521876527640788
# in next month, rate changes!!!
# current time: 2019-07-01
# months till next cyclone: 0.015453585528130483
# still in current month
# genesis date: 2019-07-01
# {'timestamp': ['2019-07-01'], 'lat': [8.8], 'lon': [172.2], 'BASIN': ['WP']}
# current time: 2019-07-01
# months till next cyclone: 0.18749533167553997
# still in current month
# genesis date: 2019-07-07
# {'timestamp': ['2019-07-07'], 'lat': [7.0], 'lon': [130.2], 'BASIN': ['WP']}
# current time: 2019-07-07
# months till next cyclone: 0.34809242099525106
# still in current month
# genesis date: 2019-07-17
# {'timestamp': ['2019-07-17'], 'lat': [13.2], 'lon': [134.5], 'BASIN': ['WP']}
# current time: 2019-07-17
# months till next cyclone: 0.17854732583945776
# still in current month
# genesis date: 2019-07-23
# {'timestamp': ['2019-07-23'], 'lat': [15.9], 'lon': [131.1], 'BASIN': ['WP']}
# current time: 2019-07-23
# months till next cyclone: 1.191284030043529
# in next month, rate changes!!!
# current time: 2019-08-01
# months till next cyclone: 0.21795451413647687
# still in current month
# genesis date: 2019-08-07
# {'timestamp': ['2019-08-07'], 'lat': [4.5], 'lon': [157.6], 'BASIN': ['WP']}
# current time: 2019-08-07
# months till next cyclone: 0.28364395135054105
# still in current month
# genesis date: 2019-08-16
# {'timestamp': ['2019-08-16'], 'lat': [7.1], 'lon': [103.7], 'BASIN': ['WP']}
# current time: 2019-08-16
# months till next cyclone: 0.3508035898029344
# still in current month
# genesis date: 2019-08-26
# {'timestamp': ['2019-08-26'], 'lat': [15.5], 'lon': [143.5], 'BASIN': ['WP']}
# current time: 2019-08-26
# months till next cyclone: 0.3511016616450503
# in next month, rate changes!!!
# current time: 2019-09-01
# months till next cyclone: 0.14687890488581665
# still in current month
# genesis date: 2019-09-05
# {'timestamp': ['2019-09-05'], 'lat': [17.2], 'lon': [146.5], 'BASIN': ['WP']}
# current time: 2019-09-05
# months till next cyclone: 0.003949934975602709
# still in current month
# genesis date: 2019-09-05
# {'timestamp': ['2019-09-05'], 'lat': [15.5], 'lon': [143.5], 'BASIN': ['WP']}
# current time: 2019-09-05
# months till next cyclone: 0.17453276982328886
# still in current month
# genesis date: 2019-09-10
# {'timestamp': ['2019-09-10'], 'lat': [7.1], 'lon': [136.9], 'BASIN': ['WP']}
# current time: 2019-09-10
# months till next cyclone: 0.13244929580239184
# still in current month
# genesis date: 2019-09-14
# {'timestamp': ['2019-09-14'], 'lat': [5.8], 'lon': [182.0], 'BASIN': ['WP']}
# current time: 2019-09-14
# months till next cyclone: 0.1681900045793007
# still in current month
# genesis date: 2019-09-20
# {'timestamp': ['2019-09-20'], 'lat': [8.1], 'lon': [160.9], 'BASIN': ['WP']}
# current time: 2019-09-20
# months till next cyclone: 0.20440445987806924
# still in current month
# genesis date: 2019-09-26
# {'timestamp': ['2019-09-26'], 'lat': [11.5], 'lon': [114.5], 'BASIN': ['WP']}
# current time: 2019-09-26
# months till next cyclone: 0.26587117765838403
# in next month, rate changes!!!
# current time: 2019-10-01
# months till next cyclone: 0.206226762703046
# still in current month
# genesis date: 2019-10-07
# {'timestamp': ['2019-10-07'], 'lat': [3.4], 'lon': [149.1], 'BASIN': ['WP']}
# current time: 2019-10-07
# months till next cyclone: 0.7103693765391755
# still in current month
# genesis date: 2019-10-28
# {'timestamp': ['2019-10-28'], 'lat': [12.6], 'lon': [146.1], 'BASIN': ['WP']}
# current time: 2019-10-28
# months till next cyclone: 0.25901833548976944
# in next month, rate changes!!!
# current time: 2019-11-01
# months till next cyclone: 0.022506636267877342
# still in current month
# genesis date: 2019-11-01
# {'timestamp': ['2019-11-01'], 'lat': [7.8], 'lon': [174.9], 'BASIN': ['WP']}
# current time: 2019-11-01
# months till next cyclone: 0.11053406141605936
# still in current month
# genesis date: 2019-11-05
# {'timestamp': ['2019-11-05'], 'lat': [8.8], 'lon': [148.8], 'BASIN': ['WP']}
# current time: 2019-11-05
# months till next cyclone: 0.11296338268012947
# still in current month
# genesis date: 2019-11-08
# {'timestamp': ['2019-11-08'], 'lat': [15.6], 'lon': [140.7], 'BASIN': ['WP']}
# current time: 2019-11-08
# months till next cyclone: 1.2265130354503575
# in next month, rate changes!!!
# current time: 2019-12-01
# months till next cyclone: 0.800772709947023
# still in current month
# genesis date: 2019-12-25
# {'timestamp': ['2019-12-25'], 'lat': [5.6], 'lon': [161.0], 'BASIN': ['WP']}
# current time: 2019-12-25
# months till next cyclone: 0.38665880419140086
# in next month, rate changes!!!
# current time: 2020-01-01
# months till next cyclone: 1.5052267812601652
# in next month, rate changes!!!
# current time: 2020-02-01
# months till next cyclone: 0.9518720690088284
# still in current month
# genesis date: 2020-02-29
# {'timestamp': ['2020-02-29'], 'lat': [8.1], 'lon': [173.3], 'BASIN': ['WP']}
# current time: 2020-02-29
# months till next cyclone: 5.524468481567571
# in next month, rate changes!!!
# current time: 2020-03-01
# months till next cyclone: 0.5123777310326484
# still in current month
# genesis date: 2020-03-16
# {'timestamp': ['2020-03-16'], 'lat': [6.1], 'lon': [150.4], 'BASIN': ['WP']}
# current time: 2020-03-16
# months till next cyclone: 2.0916967850558335
# in next month, rate changes!!!
# current time: 2020-04-01
# months till next cyclone: 3.388339028838161
# in next month, rate changes!!!
# current time: 2020-05-01
# months till next cyclone: 0.3277973462104968
# still in current month
# genesis date: 2020-05-10
# {'timestamp': ['2020-05-10'], 'lat': [1.9], 'lon': [180.2], 'BASIN': ['WP']}
# current time: 2020-05-10
# months till next cyclone: 0.5231010078628652
# still in current month
# genesis date: 2020-05-26
# {'timestamp': ['2020-05-26'], 'lat': [8.6], 'lon': [137.2], 'BASIN': ['WP']}
# current time: 2020-05-26
# months till next cyclone: 4.040452680556869
# in next month, rate changes!!!
# current time: 2020-06-01
# months till next cyclone: 0.5249596978142816
# still in current month
# genesis date: 2020-06-16
# {'timestamp': ['2020-06-16'], 'lat': [7.0], 'lon': [155.4], 'BASIN': ['WP']}
# current time: 2020-06-16
# months till next cyclone: 0.2403742622171663
# still in current month
# genesis date: 2020-06-24
# {'timestamp': ['2020-06-24'], 'lat': [9.1], 'lon': [154.0], 'BASIN': ['WP']}
# current time: 2020-06-24
# months till next cyclone: 0.37237266911147016
# in next month, rate changes!!!
# current time: 2020-07-01
# months till next cyclone: 0.663438797605842
# still in current month
# genesis date: 2020-07-21
# {'timestamp': ['2020-07-21'], 'lat': [10.0], 'lon': [190.3], 'BASIN': ['WP']}
# current time: 2020-07-21
# months till next cyclone: 0.5030320786597289
# in next month, rate changes!!!
# current time: 2020-08-01
# months till next cyclone: 0.01353106668853505
# still in current month
# genesis date: 2020-08-01
# {'timestamp': ['2020-08-01'], 'lat': [11.9], 'lon': [114.8], 'BASIN': ['WP']}
# current time: 2020-08-01
# months till next cyclone: 0.9823729886826684
# still in current month
# genesis date: 2020-08-31
# {'timestamp': ['2020-08-31'], 'lat': [8.5], 'lon': [138.9], 'BASIN': ['WP']}
# current time: 2020-08-31
# months till next cyclone: 0.08511734980215681
# in next month, rate changes!!!
# current time: 2020-09-01
# months till next cyclone: 0.03429619041655365
# still in current month
# genesis date: 2020-09-02
# {'timestamp': ['2020-09-02'], 'lat': [9.6], 'lon': [162.2], 'BASIN': ['WP']}
# current time: 2020-09-02
# months till next cyclone: 0.05623122824230671
# still in current month
# genesis date: 2020-09-03
# {'timestamp': ['2020-09-03'], 'lat': [17.0], 'lon': [168.0], 'BASIN': ['WP']}
# current time: 2020-09-03
# months till next cyclone: 0.11870411062857229
# still in current month
# genesis date: 2020-09-07
# {'timestamp': ['2020-09-07'], 'lat': [14.3], 'lon': [138.6], 'BASIN': ['WP']}
# current time: 2020-09-07
# months till next cyclone: 0.13182477709990822
# still in current month
# genesis date: 2020-09-11
# {'timestamp': ['2020-09-11'], 'lat': [6.7], 'lon': [161.1], 'BASIN': ['WP']}
# current time: 2020-09-11
# months till next cyclone: 0.2185755029988578
# still in current month
# genesis date: 2020-09-18
# {'timestamp': ['2020-09-18'], 'lat': [13.2], 'lon': [141.4], 'BASIN': ['WP']}
# current time: 2020-09-18
# months till next cyclone: 0.4223623013572097
# still in current month
# genesis date: 2020-09-30
# {'timestamp': ['2020-09-30'], 'lat': [10.6], 'lon': [118.2], 'BASIN': ['WP']}
# current time: 2020-09-30
# months till next cyclone: 0.32233010015102864
# in next month, rate changes!!!
# current time: 2020-10-01
# months till next cyclone: 0.4124454929424766
# still in current month
# genesis date: 2020-10-13
# {'timestamp': ['2020-10-13'], 'lat': [23.7], 'lon': [164.1], 'BASIN': ['WP']}
# current time: 2020-10-13
# months till next cyclone: 0.2723247319801135
# still in current month
# genesis date: 2020-10-21
# {'timestamp': ['2020-10-21'], 'lat': [11.5], 'lon': [116.2], 'BASIN': ['WP']}
# current time: 2020-10-21
# months till next cyclone: 0.18795943601680073
# still in current month
# genesis date: 2020-10-27
# {'timestamp': ['2020-10-27'], 'lat': [7.9], 'lon': [140.5], 'BASIN': ['WP']}
# current time: 2020-10-27
# months till next cyclone: 0.04974310297613571
# still in current month
# genesis date: 2020-10-29
# {'timestamp': ['2020-10-29'], 'lat': [13.1], 'lon': [159.3], 'BASIN': ['WP']}
# current time: 2020-10-29
# months till next cyclone: 0.8128187825997921
# in next month, rate changes!!!
# current time: 2020-11-01
# months till next cyclone: 0.1477704081070462
# still in current month
# genesis date: 2020-11-05
# {'timestamp': ['2020-11-05'], 'lat': [15.8], 'lon': [159.1], 'BASIN': ['WP']}
# current time: 2020-11-05
# months till next cyclone: 0.07609150922424278
# still in current month
# genesis date: 2020-11-07
# {'timestamp': ['2020-11-07'], 'lat': [3.8], 'lon': [178.6], 'BASIN': ['WP']}
# current time: 2020-11-07
# months till next cyclone: 0.19885842782239582
# still in current month
# genesis date: 2020-11-13
# {'timestamp': ['2020-11-13'], 'lat': [4.5], 'lon': [157.6], 'BASIN': ['WP']}
# current time: 2020-11-13
# months till next cyclone: 0.31118208328489244
# still in current month
# genesis date: 2020-11-23
# {'timestamp': ['2020-11-23'], 'lat': [24.3], 'lon': [145.1], 'BASIN': ['WP']}
# current time: 2020-11-23
# months till next cyclone: 0.7902076244268823
# in next month, rate changes!!!
# current time: 2020-12-01
# months till next cyclone: 0.36383481749458996
# still in current month
# genesis date: 2020-12-12
# {'timestamp': ['2020-12-12'], 'lat': [15.7], 'lon': [117.0], 'BASIN': ['WP']}
# current time: 2020-12-12
# months till next cyclone: 0.6354648750100804
# still in current month
# genesis date: 2020-12-31
# {'timestamp': ['2020-12-31'], 'lat': [18.0], 'lon': [119.6], 'BASIN': ['WP']}
# current time: 2020-12-31
# months till next cyclone: 0.7460041501117246
# in next month, rate changes!!!
# current time: 2021-01-01
# months till next cyclone: 4.500000209115027
# in next month, rate changes!!!
# current time: 2021-02-01
# months till next cyclone: 4.92597226162882
# in next month, rate changes!!!
# current time: 2021-03-01
# months till next cyclone: 0.1627787628598213
# still in current month
# genesis date: 2021-03-05
# {'timestamp': ['2021-03-05'], 'lat': [11.3], 'lon': [167.5], 'BASIN': ['WP']}
# current time: 2021-03-05
# months till next cyclone: 3.134528813257065
# in next month, rate changes!!!
# current time: 2021-04-01
# months till next cyclone: 1.093985767452437
# in next month, rate changes!!!
# current time: 2021-05-01
# months till next cyclone: 0.26263332007131357
# still in current month
# genesis date: 2021-05-08
# {'timestamp': ['2021-05-08'], 'lat': [18.5], 'lon': [152.9], 'BASIN': ['WP']}
# current time: 2021-05-08
# months till next cyclone: 1.1146875252796016
# in next month, rate changes!!!
# current time: 2021-06-01
# months till next cyclone: 0.9428848217558925
# still in current month
# genesis date: 2021-06-29
# {'timestamp': ['2021-06-29'], 'lat': [15.6], 'lon': [140.7], 'BASIN': ['WP']}
# current time: 2021-06-29
# months till next cyclone: 0.6270568368866587
# in next month, rate changes!!!
# current time: 2021-07-01
# months till next cyclone: 0.10884975685332036
# still in current month
# genesis date: 2021-07-04
# {'timestamp': ['2021-07-04'], 'lat': [3.9], 'lon': [145.0], 'BASIN': ['WP']}
# current time: 2021-07-04
# months till next cyclone: 0.25827254916838555
# still in current month
# genesis date: 2021-07-12
# {'timestamp': ['2021-07-12'], 'lat': [18.8], 'lon': [119.1], 'BASIN': ['WP']}
# current time: 2021-07-12
# months till next cyclone: 0.19450868514824307
# still in current month
# genesis date: 2021-07-18
# {'timestamp': ['2021-07-18'], 'lat': [12.0], 'lon': [128.0], 'BASIN': ['WP']}
# current time: 2021-07-18
# months till next cyclone: 0.1458842847306821
# still in current month
# genesis date: 2021-07-22
# {'timestamp': ['2021-07-22'], 'lat': [16.8], 'lon': [146.7], 'BASIN': ['WP']}
# current time: 2021-07-22
# months till next cyclone: 0.09747434313716673
# still in current month
# genesis date: 2021-07-25
# {'timestamp': ['2021-07-25'], 'lat': [21.4], 'lon': [135.6], 'BASIN': ['WP']}
# current time: 2021-07-25
# months till next cyclone: 0.30434265532378557
# in next month, rate changes!!!
# current time: 2021-08-01
# months till next cyclone: 0.1247047531118139
# still in current month
# genesis date: 2021-08-04
# {'timestamp': ['2021-08-04'], 'lat': [6.6], 'lon': [173.3], 'BASIN': ['WP']}
# current time: 2021-08-04
# months till next cyclone: 0.23674347019319786
# still in current month
# genesis date: 2021-08-12
# {'timestamp': ['2021-08-12'], 'lat': [12.0], 'lon': [144.0], 'BASIN': ['WP']}
# current time: 2021-08-12
# months till next cyclone: 0.022625754700229858
# still in current month
# genesis date: 2021-08-12
# {'timestamp': ['2021-08-12'], 'lat': [17.2], 'lon': [153.4], 'BASIN': ['WP']}
# current time: 2021-08-12
# months till next cyclone: 0.15821212609673416
# still in current month
# genesis date: 2021-08-17
# {'timestamp': ['2021-08-17'], 'lat': [22.4], 'lon': [173.4], 'BASIN': ['WP']}
# current time: 2021-08-17
# months till next cyclone: 0.11272813386861003
# still in current month
# genesis date: 2021-08-20
# {'timestamp': ['2021-08-20'], 'lat': [9.8], 'lon': [130.4], 'BASIN': ['WP']}
# current time: 2021-08-20
# months till next cyclone: 0.04646260094373208
# still in current month
# genesis date: 2021-08-22
# {'timestamp': ['2021-08-22'], 'lat': [16.2], 'lon': [132.2], 'BASIN': ['WP']}
# current time: 2021-08-22
# months till next cyclone: 0.27079328973785316
# still in current month
# genesis date: 2021-08-30
# {'timestamp': ['2021-08-30'], 'lat': [15.4], 'lon': [112.2], 'BASIN': ['WP']}
# current time: 2021-08-30
# months till next cyclone: 0.1036539235528572
# in next month, rate changes!!!
# current time: 2021-09-01
# months till next cyclone: 0.004329290710024172
# still in current month
# genesis date: 2021-09-01
# {'timestamp': ['2021-09-01'], 'lat': [11.4], 'lon': [162.5], 'BASIN': ['WP']}
# current time: 2021-09-01
# months till next cyclone: 0.28590967115956895
# still in current month
# genesis date: 2021-09-09
# {'timestamp': ['2021-09-09'], 'lat': [11.5], 'lon': [114.5], 'BASIN': ['WP']}
# current time: 2021-09-09
# months till next cyclone: 0.1007554172937265
# still in current month
# genesis date: 2021-09-12
# {'timestamp': ['2021-09-12'], 'lat': [13.2], 'lon': [146.8], 'BASIN': ['WP']}
# current time: 2021-09-12
# months till next cyclone: 0.14632820705997499
# still in current month
# genesis date: 2021-09-17
# {'timestamp': ['2021-09-17'], 'lat': [9.9], 'lon': [111.2], 'BASIN': ['WP']}
# current time: 2021-09-17
# months till next cyclone: 0.14440575607486988
# still in current month
# genesis date: 2021-09-21
# {'timestamp': ['2021-09-21'], 'lat': [6.9], 'lon': [153.6], 'BASIN': ['WP']}
# current time: 2021-09-21
# months till next cyclone: 0.20180502010917478
# still in current month
# genesis date: 2021-09-27
# {'timestamp': ['2021-09-27'], 'lat': [17.8], 'lon': [138.2], 'BASIN': ['WP']}
# current time: 2021-09-27
# months till next cyclone: 0.1156490693914527
# in next month, rate changes!!!
# current time: 2021-10-01
# months till next cyclone: 0.3423328110686823
# still in current month
# genesis date: 2021-10-11
# {'timestamp': ['2021-10-11'], 'lat': [12.6], 'lon': [135.4], 'BASIN': ['WP']}
# current time: 2021-10-11
# months till next cyclone: 0.2145359969916368
# still in current month
# genesis date: 2021-10-17
# {'timestamp': ['2021-10-17'], 'lat': [17.5], 'lon': [161.4], 'BASIN': ['WP']}
# current time: 2021-10-17
# months till next cyclone: 0.08314221863875604
# still in current month
# genesis date: 2021-10-20
# {'timestamp': ['2021-10-20'], 'lat': [18.1], 'lon': [152.3], 'BASIN': ['WP']}
# current time: 2021-10-20
# months till next cyclone: 0.03985317944353305
# still in current month
# genesis date: 2021-10-21
# {'timestamp': ['2021-10-21'], 'lat': [7.0], 'lon': [151.3], 'BASIN': ['WP']}
# current time: 2021-10-21
# months till next cyclone: 0.31249365963902853
# still in current month
# genesis date: 2021-10-31
# {'timestamp': ['2021-10-31'], 'lat': [6.6], 'lon': [161.6], 'BASIN': ['WP']}
# current time: 2021-10-31
# months till next cyclone: 0.1011403073256886
# in next month, rate changes!!!
# current time: 2021-11-01
# months till next cyclone: 0.05953001263997229
# still in current month
# genesis date: 2021-11-02
# {'timestamp': ['2021-11-02'], 'lat': [13.7], 'lon': [160.8], 'BASIN': ['WP']}
# current time: 2021-11-02
# months till next cyclone: 0.4379392506241379
# still in current month
# genesis date: 2021-11-16
# {'timestamp': ['2021-11-16'], 'lat': [7.9], 'lon': [162.9], 'BASIN': ['WP']}
# current time: 2021-11-16
# months till next cyclone: 0.33054087800190735
# still in current month
# genesis date: 2021-11-26
# {'timestamp': ['2021-11-26'], 'lat': [19.5], 'lon': [160.1], 'BASIN': ['WP']}
# current time: 2021-11-26
# months till next cyclone: 0.3543509242241006
# in next month, rate changes!!!
# current time: 2021-12-01
# months till next cyclone: 0.5914763518201496
# still in current month
# genesis date: 2021-12-19
# {'timestamp': ['2021-12-19'], 'lat': [13.2], 'lon': [140.7], 'BASIN': ['WP']}
# current time: 2021-12-19
# months till next cyclone: 1.1019650174164932
# in next month, rate changes!!!
# current time: 2022-01-01
# months till next cyclone: 5.661538922365382
# in next month, rate changes!!!
# current time: 2022-02-01
# months till next cyclone: 0.6020638520078513
# still in current month
# genesis date: 2022-02-19
# {'timestamp': ['2022-02-19'], 'lat': [5.2], 'lon': [155.5], 'BASIN': ['WP']}
# current time: 2022-02-19
# months till next cyclone: 2.319943598255098
# in next month, rate changes!!!
# current time: 2022-03-01
# months till next cyclone: 0.8436274232482954
# still in current month
# genesis date: 2022-03-26
# {'timestamp': ['2022-03-26'], 'lat': [8.4], 'lon': [131.4], 'BASIN': ['WP']}
# current time: 2022-03-26
# months till next cyclone: 1.1814481594636745
# in next month, rate changes!!!
# current time: 2022-04-01
# months till next cyclone: 0.7256108137946755
# still in current month
# genesis date: 2022-04-23
# {'timestamp': ['2022-04-23'], 'lat': [4.0], 'lon': [176.0], 'BASIN': ['WP']}
# current time: 2022-04-23
# months till next cyclone: 4.070365858046918
# in next month, rate changes!!!
# current time: 2022-05-01
# months till next cyclone: 0.049421428225389835
# still in current month
# genesis date: 2022-05-02
# {'timestamp': ['2022-05-02'], 'lat': [10.9], 'lon': [161.8], 'BASIN': ['WP']}
# current time: 2022-05-02
# months till next cyclone: 0.5669127116859365
# still in current month
# genesis date: 2022-05-19
# {'timestamp': ['2022-05-19'], 'lat': [20.5], 'lon': [135.1], 'BASIN': ['WP']}
# current time: 2022-05-19
# months till next cyclone: 0.5784849259961639
# in next month, rate changes!!!
# current time: 2022-06-01
# months till next cyclone: 0.7187679983442099
# still in current month
# genesis date: 2022-06-22
# {'timestamp': ['2022-06-22'], 'lat': [15.2], 'lon': [137.3], 'BASIN': ['WP']}
# current time: 2022-06-22
# months till next cyclone: 0.6522053946462175
# in next month, rate changes!!!
# current time: 2022-07-01
# months till next cyclone: 0.34133994011707275
# still in current month
# genesis date: 2022-07-11
# {'timestamp': ['2022-07-11'], 'lat': [20.6], 'lon': [169.6], 'BASIN': ['WP']}
# current time: 2022-07-11
# months till next cyclone: 0.10455500547573815
# still in current month
# genesis date: 2022-07-14
# {'timestamp': ['2022-07-14'], 'lat': [11.1], 'lon': [133.5], 'BASIN': ['WP']}
# current time: 2022-07-14
# months till next cyclone: 0.007801390865158339
# still in current month
# genesis date: 2022-07-14
# {'timestamp': ['2022-07-14'], 'lat': [6.2], 'lon': [152.8], 'BASIN': ['WP']}
# current time: 2022-07-14
# months till next cyclone: 0.6119913323457645
# in next month, rate changes!!!
# current time: 2022-08-01
# months till next cyclone: 0.3350475178521735
# still in current month
# genesis date: 2022-08-11
# {'timestamp': ['2022-08-11'], 'lat': [9.8], 'lon': [183.2], 'BASIN': ['WP']}
# current time: 2022-08-11
# months till next cyclone: 0.040959731897620505
# still in current month
# genesis date: 2022-08-12
# {'timestamp': ['2022-08-12'], 'lat': [15.6], 'lon': [153.6], 'BASIN': ['WP']}
# current time: 2022-08-12
# months till next cyclone: 0.3299008142246309
# still in current month
# genesis date: 2022-08-22
# {'timestamp': ['2022-08-22'], 'lat': [20.1], 'lon': [126.1], 'BASIN': ['WP']}
# current time: 2022-08-22
# months till next cyclone: 0.028110447504716415
# still in current month
# genesis date: 2022-08-23
# {'timestamp': ['2022-08-23'], 'lat': [19.8], 'lon': [127.0], 'BASIN': ['WP']}
# current time: 2022-08-23
# months till next cyclone: 0.09947621382375951
# still in current month
# genesis date: 2022-08-26
# {'timestamp': ['2022-08-26'], 'lat': [4.0], 'lon': [175.0], 'BASIN': ['WP']}
# current time: 2022-08-26
# months till next cyclone: 0.13946956661854473
# still in current month
# genesis date: 2022-08-30
# {'timestamp': ['2022-08-30'], 'lat': [17.0], 'lon': [168.0], 'BASIN': ['WP']}
# current time: 2022-08-30
# months till next cyclone: 0.4703138043097834
# in next month, rate changes!!!
# current time: 2022-09-01
# months till next cyclone: 0.03844435842583916
# still in current month
# genesis date: 2022-09-02
# {'timestamp': ['2022-09-02'], 'lat': [15.5], 'lon': [111.0], 'BASIN': ['WP']}
# current time: 2022-09-02
# months till next cyclone: 0.1615852825676015
# still in current month
# genesis date: 2022-09-07
# {'timestamp': ['2022-09-07'], 'lat': [27.0], 'lon': [135.0], 'BASIN': ['WP']}
# current time: 2022-09-07
# months till next cyclone: 0.04930413071479417
# still in current month
# genesis date: 2022-09-08
# {'timestamp': ['2022-09-08'], 'lat': [14.1], 'lon': [129.4], 'BASIN': ['WP']}
# current time: 2022-09-08
# months till next cyclone: 0.5259261104431803
# still in current month
# genesis date: 2022-09-24
# {'timestamp': ['2022-09-24'], 'lat': [8.2], 'lon': [155.8], 'BASIN': ['WP']}
# current time: 2022-09-24
# months till next cyclone: 0.10904146230973699
# still in current month
# genesis date: 2022-09-27
# {'timestamp': ['2022-09-27'], 'lat': [3.4], 'lon': [155.9], 'BASIN': ['WP']}
# current time: 2022-09-27
# months till next cyclone: 0.6647591856863136
# in next month, rate changes!!!
# current time: 2022-10-01
# months till next cyclone: 0.5356627856648183
# still in current month
# genesis date: 2022-10-17
# ...
# {'timestamp': ['2043-06-15'], 'lat': [-12.6], 'lon': [151.2], 'BASIN': ['SP']}
# current time: 2043-06-15
# months till next cyclone: 13.50305854387404
# in next month, rate changes!!!
# current time: 2043-07-01
# months till next cyclone: 14.898679067717783
# in next month, rate changes!!!
# current time: 2043-08-01
# no cyclones, skipping month
# current time: 2043-09-01
# months till next cyclone: 34.85832490981204
# in next month, rate changes!!!
# current time: 2043-10-01
# months till next cyclone: 18.644112663689445
# in next month, rate changes!!!
# current time: 2043-11-01
# months till next cyclone: 0.4437851806395843
# still in current month
# genesis date: 2043-11-14
# {'timestamp': ['2043-11-14'], 'lat': [-8.3], 'lon': [171.4], 'BASIN': ['SP']}
# current time: 2043-11-14
# months till next cyclone: 4.242415416419102
# in next month, rate changes!!!
# current time: 2043-12-01
# months till next cyclone: 0.11919014910510568
# still in current month
# genesis date: 2043-12-04
# {'timestamp': ['2043-12-04'], 'lat': [-10.0], 'lon': [228.6], 'BASIN': ['SP']}
# current time: 2043-12-04
# months till next cyclone: 4.009762142910932
# in next month, rate changes!!!
# current time: 2044-01-01
# months till next cyclone: 0.5365799499161574
# still in current month
# genesis date: 2044-01-17
# {'timestamp': ['2044-01-17'], 'lat': [-17.4], 'lon': [149.0], 'BASIN': ['SP']}
# current time: 2044-01-17
# months till next cyclone: 0.09436159637511014
# still in current month
# genesis date: 2044-01-20
# {'timestamp': ['2044-01-20'], 'lat': [-15.7], 'lon': [154.2], 'BASIN': ['SP']}
# current time: 2044-01-20
# months till next cyclone: 0.5993637532745716
# in next month, rate changes!!!
# current time: 2044-02-01
# months till next cyclone: 1.0985538300858557
# in next month, rate changes!!!
# current time: 2044-03-01
# months till next cyclone: 0.4547929764815762
# still in current month
# genesis date: 2044-03-14
# {'timestamp': ['2044-03-14'], 'lat': [-11.0], 'lon': [178.1], 'BASIN': ['SP']}
# current time: 2044-03-14
# months till next cyclone: 0.2294553629620458
# still in current month
# genesis date: 2044-03-21
# {'timestamp': ['2044-03-21'], 'lat': [-9.9], 'lon': [171.2], 'BASIN': ['SP']}
# current time: 2044-03-21
# months till next cyclone: 1.375515359399285
# in next month, rate changes!!!
# current time: 2044-04-01
# months till next cyclone: 0.8507863226787327
# still in current month
# genesis date: 2044-04-26
# {'timestamp': ['2044-04-26'], 'lat': [-14.6], 'lon': [168.0], 'BASIN': ['SP']}
# current time: 2044-04-26
# months till next cyclone: 0.5036225792495005
# in next month, rate changes!!!
# current time: 2044-05-01
# months till next cyclone: 7.341331804041242
# in next month, rate changes!!!
# current time: 2044-06-01
# months till next cyclone: 3.0541644506533814
# in next month, rate changes!!!
# current time: 2044-07-01
# months till next cyclone: 40.8768497548126
# in next month, rate changes!!!
# current time: 2044-08-01
# no cyclones, skipping month
# current time: 2044-09-01
# months till next cyclone: 32.14478130277759
# in next month, rate changes!!!
# current time: 2044-10-01
# months till next cyclone: 0.04912344013334281
# still in current month
# genesis date: 2044-10-02
# {'timestamp': ['2044-10-02'], 'lat': [-12.2], 'lon': [145.3], 'BASIN': ['SP']}
# current time: 2044-10-02
# months till next cyclone: 5.6296204421175835
# in next month, rate changes!!!
# current time: 2044-11-01
# months till next cyclone: 0.35424857701429
# still in current month
# genesis date: 2044-11-11
# {'timestamp': ['2044-11-11'], 'lat': [-13.1], 'lon': [185.7], 'BASIN': ['SP']}
# current time: 2044-11-11
# months till next cyclone: 5.156553587870113
# in next month, rate changes!!!
# current time: 2044-12-01
# months till next cyclone: 1.1457115954668247
# in next month, rate changes!!!
# current time: 2045-01-01
# months till next cyclone: 0.922494184100903
# still in current month
# genesis date: 2045-01-29
# {'timestamp': ['2045-01-29'], 'lat': [-14.9], 'lon': [172.2], 'BASIN': ['SP']}
# current time: 2045-01-29
# months till next cyclone: 0.40832725305161166
# in next month, rate changes!!!
# current time: 2045-02-01
# months till next cyclone: 1.2130808302946925
# in next month, rate changes!!!
# current time: 2045-03-01
# months till next cyclone: 0.33119613534134096
# still in current month
# genesis date: 2045-03-11
# {'timestamp': ['2045-03-11'], 'lat': [-13.9], 'lon': [171.8], 'BASIN': ['SP']}
# current time: 2045-03-11
# months till next cyclone: 0.42482015972892306
# still in current month
# genesis date: 2045-03-24
# {'timestamp': ['2045-03-24'], 'lat': [-10.3], 'lon': [172.1], 'BASIN': ['SP']}
# current time: 2045-03-24
# months till next cyclone: 0.24868398972631214
# still in current month
# genesis date: 2045-03-31
# {'timestamp': ['2045-03-31'], 'lat': [-10.3], 'lon': [224.4], 'BASIN': ['SP']}
# current time: 2045-03-31
# months till next cyclone: 0.07625834843754464
# in next month, rate changes!!!
# current time: 2045-04-01
# months till next cyclone: 1.0686251201940105
# in next month, rate changes!!!
# current time: 2045-05-01
# months till next cyclone: 11.600955722404903
# in next month, rate changes!!!
# current time: 2045-06-01
# months till next cyclone: 32.977383472199094
# in next month, rate changes!!!
# current time: 2045-07-01
# months till next cyclone: 44.01091682613921
# in next month, rate changes!!!
# current time: 2045-08-01
# no cyclones, skipping month
# current time: 2045-09-01
# months till next cyclone: 35.14272229259173
# in next month, rate changes!!!
# current time: 2045-10-01
# months till next cyclone: 13.961402019098886
# in next month, rate changes!!!
# current time: 2045-11-01
# months till next cyclone: 2.214162094077977
# in next month, rate changes!!!
# current time: 2045-12-01
# months till next cyclone: 0.667096161653171
# still in current month
# genesis date: 2045-12-21
# {'timestamp': ['2045-12-21'], 'lat': [-17.5], 'lon': [188.8], 'BASIN': ['SP']}
# current time: 2045-12-21
# months till next cyclone: 0.6645377939878269
# in next month, rate changes!!!
# current time: 2046-01-01
# months till next cyclone: 0.444766134509581
# still in current month
# genesis date: 2046-01-14
# {'timestamp': ['2046-01-14'], 'lat': [-12.8], 'lon': [217.3], 'BASIN': ['SP']}
# current time: 2046-01-14
# months till next cyclone: 0.054598228454522904
# still in current month
# genesis date: 2046-01-16
# {'timestamp': ['2046-01-16'], 'lat': [-9.5], 'lon': [179.1], 'BASIN': ['SP']}
# current time: 2046-01-16
# months till next cyclone: 0.01050131969056972
# still in current month
# genesis date: 2046-01-16
# {'timestamp': ['2046-01-16'], 'lat': [-15.4], 'lon': [172.1], 'BASIN': ['SP']}
# current time: 2046-01-16
# months till next cyclone: 0.6123244977726715
# in next month, rate changes!!!
# current time: 2046-02-01
# months till next cyclone: 0.7489793883857154
# still in current month
# genesis date: 2046-02-23
# {'timestamp': ['2046-02-23'], 'lat': [-15.7], 'lon': [154.2], 'BASIN': ['SP']}
# current time: 2046-02-23
# months till next cyclone: 0.12442657461035166
# still in current month
# genesis date: 2046-02-27
# {'timestamp': ['2046-02-27'], 'lat': [-14.9], 'lon': [149.7], 'BASIN': ['SP']}
# current time: 2046-02-27
# months till next cyclone: 0.04238162847946381
# still in current month
# genesis date: 2046-02-28
# {'timestamp': ['2046-02-28'], 'lat': [-7.6], 'lon': [168.9], 'BASIN': ['SP']}
# current time: 2046-02-28
# months till next cyclone: 0.03892512082069394
# in next month, rate changes!!!
# current time: 2046-03-01
# months till next cyclone: 0.6825242881260596
# still in current month
# genesis date: 2046-03-21
# {'timestamp': ['2046-03-21'], 'lat': [-15.1], 'lon': [158.9], 'BASIN': ['SP']}
# current time: 2046-03-21
# months till next cyclone: 0.08370869315843263
# still in current month
# genesis date: 2046-03-24
# {'timestamp': ['2046-03-24'], 'lat': [-14.6], 'lon': [156.2], 'BASIN': ['SP']}
# current time: 2046-03-24
# months till next cyclone: 1.0507403541148028
# in next month, rate changes!!!
# current time: 2046-04-01
# months till next cyclone: 0.753060281858248
# still in current month
# genesis date: 2046-04-23
# {'timestamp': ['2046-04-23'], 'lat': [-8.7], 'lon': [178.2], 'BASIN': ['SP']}
# current time: 2046-04-23
# months till next cyclone: 0.1834215383742915
# still in current month
# genesis date: 2046-04-29
# {'timestamp': ['2046-04-29'], 'lat': [-14.8], 'lon': [155.4], 'BASIN': ['SP']}
# current time: 2046-04-29
# months till next cyclone: 1.395471575710842
# in next month, rate changes!!!
# current time: 2046-05-01
# months till next cyclone: 1.867460998290556
# in next month, rate changes!!!
# current time: 2046-06-01
# months till next cyclone: 10.292418935108198
# in next month, rate changes!!!
# current time: 2046-07-01
# months till next cyclone: 145.97415243383062
# in next month, rate changes!!!
# current time: 2046-08-01
# no cyclones, skipping month
# current time: 2046-09-01
# months till next cyclone: 0.9028924257270117
# still in current month
# genesis date: 2046-09-28
# {'timestamp': ['2046-09-28'], 'lat': [-15.1], 'lon': [192.7], 'BASIN': ['SP']}
# current time: 2046-09-28
# months till next cyclone: 54.32648192682319
# in next month, rate changes!!!
# current time: 2046-10-01
# months till next cyclone: 11.75908381549987
# in next month, rate changes!!!
# current time: 2046-11-01
# months till next cyclone: 4.495433689262169
# in next month, rate changes!!!
# current time: 2046-12-01
# months till next cyclone: 0.09226553151904646
# still in current month
# genesis date: 2046-12-03
# {'timestamp': ['2046-12-03'], 'lat': [-14.0], 'lon': [162.4], 'BASIN': ['SP']}
# current time: 2046-12-03
# months till next cyclone: 0.22358553812427395
# still in current month
# genesis date: 2046-12-10
# {'timestamp': ['2046-12-10'], 'lat': [-14.0], 'lon': [171.6], 'BASIN': ['SP']}
# current time: 2046-12-10
# months till next cyclone: 1.7514287730608666
# in next month, rate changes!!!
# current time: 2047-01-01
# months till next cyclone: 0.9316003545619743
# still in current month
# genesis date: 2047-01-29
# {'timestamp': ['2047-01-29'], 'lat': [-14.5], 'lon': [150.2], 'BASIN': ['SP']}
# current time: 2047-01-29
# months till next cyclone: 0.24162706691326652
# in next month, rate changes!!!
# current time: 2047-02-01
# months till next cyclone: 0.5279454471853089
# still in current month
# genesis date: 2047-02-17
# {'timestamp': ['2047-02-17'], 'lat': [-13.9], 'lon': [178.0], 'BASIN': ['SP']}
# current time: 2047-02-17
# months till next cyclone: 1.0025129210420374
# in next month, rate changes!!!
# current time: 2047-03-01
# months till next cyclone: 3.279389022803171
# in next month, rate changes!!!
# current time: 2047-04-01
# months till next cyclone: 2.1343871376546018
# in next month, rate changes!!!
# current time: 2047-05-01
# months till next cyclone: 0.7418373246391881
# still in current month
# genesis date: 2047-05-23
# {'timestamp': ['2047-05-23'], 'lat': [-21.5], 'lon': [206.2], 'BASIN': ['SP']}
# current time: 2047-05-23
# months till next cyclone: 22.834357816205692
# in next month, rate changes!!!
# current time: 2047-06-01
# months till next cyclone: 0.25390264254364425
# still in current month
# genesis date: 2047-06-08
# {'timestamp': ['2047-06-08'], 'lat': [-11.1], 'lon': [169.7], 'BASIN': ['SP']}
# current time: 2047-06-08
# months till next cyclone: 4.967937831465885
# in next month, rate changes!!!
# current time: 2047-07-01
# months till next cyclone: 5.437887821239348
# in next month, rate changes!!!
# current time: 2047-08-01
# no cyclones, skipping month
# current time: 2047-09-01
# months till next cyclone: 21.941571423248185
# in next month, rate changes!!!
# current time: 2047-10-01
# months till next cyclone: 11.418972014409306
# in next month, rate changes!!!
# current time: 2047-11-01
# months till next cyclone: 2.0568942939802266
# in next month, rate changes!!!
# current time: 2047-12-01
# months till next cyclone: 0.14882738586295707
# still in current month
# genesis date: 2047-12-05
# {'timestamp': ['2047-12-05'], 'lat': [-14.3], 'lon': [180.0], 'BASIN': ['SP']}
# current time: 2047-12-05
# months till next cyclone: 6.08517035777452
# in next month, rate changes!!!
# current time: 2048-01-01
# months till next cyclone: 0.9088411734760155
# still in current month
# genesis date: 2048-01-28
# {'timestamp': ['2048-01-28'], 'lat': [-15.0], 'lon': [170.0], 'BASIN': ['SP']}
# current time: 2048-01-28
# months till next cyclone: 0.33500517276806585
# in next month, rate changes!!!
# current time: 2048-02-01
# months till next cyclone: 0.21350564226910898
# still in current month
# genesis date: 2048-02-07
# {'timestamp': ['2048-02-07'], 'lat': [-14.3], 'lon': [150.7], 'BASIN': ['SP']}
# current time: 2048-02-07
# months till next cyclone: 0.41937744452786374
# still in current month
# genesis date: 2048-02-20
# {'timestamp': ['2048-02-20'], 'lat': [-11.3], 'lon': [165.0], 'BASIN': ['SP']}
# current time: 2048-02-20
# months till next cyclone: 0.49709950368450445
# in next month, rate changes!!!
# current time: 2048-03-01
# months till next cyclone: 0.3806070109422269
# still in current month
# genesis date: 2048-03-12
# {'timestamp': ['2048-03-12'], 'lat': [-9.1], 'lon': [195.1], 'BASIN': ['SP']}
# current time: 2048-03-12
# months till next cyclone: 0.5976803613826265
# still in current month
# genesis date: 2048-03-30
# {'timestamp': ['2048-03-30'], 'lat': [-10.0], 'lon': [154.5], 'BASIN': ['SP']}
# current time: 2048-03-30
# months till next cyclone: 0.8068788536543507
# in next month, rate changes!!!
# current time: 2048-04-01
# months till next cyclone: 3.2271431641017774
# in next month, rate changes!!!
# current time: 2048-05-01
# months till next cyclone: 6.255408601551355
# in next month, rate changes!!!
# current time: 2048-06-01
# months till next cyclone: 15.249551863557334
# in next month, rate changes!!!
# current time: 2048-07-01
# months till next cyclone: 7.774480115253587
# in next month, rate changes!!!
# current time: 2048-08-01
# no cyclones, skipping month
# current time: 2048-09-01
# months till next cyclone: 54.88586242841761
# in next month, rate changes!!!
# current time: 2048-10-01
# months till next cyclone: 5.671227627367018
# in next month, rate changes!!!
# current time: 2048-11-01
# months till next cyclone: 1.909528978695927
# in next month, rate changes!!!
# current time: 2048-12-01
# months till next cyclone: 0.11822315160663358
# still in current month
# genesis date: 2048-12-04
# {'timestamp': ['2048-12-04'], 'lat': [-12.6], 'lon': [163.1], 'BASIN': ['SP']}
# current time: 2048-12-04
# months till next cyclone: 1.1315426690084003
# in next month, rate changes!!!
# current time: 2049-01-01
# months till next cyclone: 1.1817030429601112
# in next month, rate changes!!!
# current time: 2049-02-01
# months till next cyclone: 0.03365520124580614
# still in current month
# genesis date: 2049-02-02
# {'timestamp': ['2049-02-02'], 'lat': [-11.1], 'lon': [169.7], 'BASIN': ['SP']}
# current time: 2049-02-02
# months till next cyclone: 0.17731021091698085
# still in current month
# genesis date: 2049-02-07
# {'timestamp': ['2049-02-07'], 'lat': [-11.2], 'lon': [180.3], 'BASIN': ['SP']}
# current time: 2049-02-07
# months till next cyclone: 0.48899065736197117
# still in current month
# genesis date: 2049-02-22
# {'timestamp': ['2049-02-22'], 'lat': [-16.1], 'lon': [161.4], 'BASIN': ['SP']}
# current time: 2049-02-22
# months till next cyclone: 0.6636768467521256
# in next month, rate changes!!!
# current time: 2049-03-01
# months till next cyclone: 1.7485929213963949
# in next month, rate changes!!!
# current time: 2049-04-01
# months till next cyclone: 0.040523015031592224
# still in current month
# genesis date: 2049-04-02
# {'timestamp': ['2049-04-02'], 'lat': [-9.5], 'lon': [182.4], 'BASIN': ['SP']}
# current time: 2049-04-02
# months till next cyclone: 1.1809988399080709
# in next month, rate changes!!!
# current time: 2049-05-01
# months till next cyclone: 5.3030744846091284
# in next month, rate changes!!!
# current time: 2049-06-01
# months till next cyclone: 5.630109563738341
# in next month, rate changes!!!
# current time: 2049-07-01
# months till next cyclone: 17.321626719044875
# in next month, rate changes!!!
# current time: 2049-08-01
# no cyclones, skipping month
# current time: 2049-09-01
# months till next cyclone: 82.87483300126898
# in next month, rate changes!!!
# current time: 2049-10-01
# months till next cyclone: 27.44910249165374
# in next month, rate changes!!!
# current time: 2049-11-01
# months till next cyclone: 3.6890158553754273
# in next month, rate changes!!!
# current time: 2049-12-01
# months till next cyclone: 1.053326106707052
# in next month, rate changes!!!

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cartopy.crs as ccrs

## only show origin sites for now
min_long = new_cyclones['lon'].min()
min_lat = new_cyclones['lat'].min()

max_long = new_cyclones['lon'].max()
max_lat = new_cyclones['lat'].max()

centre_long = (max_long-min_long)/2

print('latitude: ' + str(min_lat) + ' to ' + str(max_lat))
print('longitude: ' + str(min_long) + ' to ' + str(max_long))

height = 5
fig = plt.figure(figsize=((max_long - min_long)/(max_lat-min_lat)*height, height))
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude= centre_long))
ax.set_extent([min_long - 10, max_long + 10 ,min_lat - 10,max_lat + 10], ccrs.PlateCarree())
ax.coastlines()
ax.stock_img()

scatter = plt.scatter(x=new_cyclones['lon'], y=new_cyclones['lat'], transform=ccrs.PlateCarree(), s=35)

fig.tight_layout()
plt.show()

# fig.savefig('./media/Cyclone/cyclone_map/all_cyclones.png')
# Out:
# latitude: -24.0 to 30.3
# longitude: 32.3 to 228.6
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/climateProjectEnv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/mambaforge/envs/climateProjectEnv/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/mambaforge/envs/climateProjectEnv/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'relative_sst'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/albertdemskoy/Documents/Uni Local/5thYear/HonoursProject/repos/cyclonegenesis_seasurfacetemperature/Climate Project/albert/notebooks/future_cyclones.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell:/Users/albertdemskoy/Documents/Uni%20Local/5thYear/HonoursProject/repos/cyclonegenesis_seasurfacetemperature/Climate%20Project/albert/notebooks/future_cyclones.ipynb#W3sZmlsZQ%3D%3D?line=20'>21</a> ax.coastlines()
#      <a href='vscode-notebook-cell:/Users/albertdemskoy/Documents/Uni%20Local/5thYear/HonoursProject/repos/cyclonegenesis_seasurfacetemperature/Climate%20Project/albert/notebooks/future_cyclones.ipynb#W3sZmlsZQ%3D%3D?line=21'>22</a> ax.stock_img()
# ---> <a href='vscode-notebook-cell:/Users/albertdemskoy/Documents/Uni%20Local/5thYear/HonoursProject/repos/cyclonegenesis_seasurfacetemperature/Climate%20Project/albert/notebooks/future_cyclones.ipynb#W3sZmlsZQ%3D%3D?line=23'>24</a> scatter = plt.scatter(x=new_cyclones['lon'], y=new_cyclones['lat'], hue=new_cyclone['relative_sst'], transform=ccrs.PlateCarree(), s=35)
#      <a href='vscode-notebook-cell:/Users/albertdemskoy/Documents/Uni%20Local/5thYear/HonoursProject/repos/cyclonegenesis_seasurfacetemperature/Climate%20Project/albert/notebooks/future_cyclones.ipynb#W3sZmlsZQ%3D%3D?line=25'>26</a> fig.tight_layout()
#      <a href='vscode-notebook-cell:/Users/albertdemskoy/Documents/Uni%20Local/5thYear/HonoursProject/repos/cyclonegenesis_seasurfacetemperature/Climate%20Project/albert/notebooks/future_cyclones.ipynb#W3sZmlsZQ%3D%3D?line=26'>27</a> plt.show()
#
# File ~/mambaforge/envs/climateProjectEnv/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/mambaforge/envs/climateProjectEnv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'relative_sst'
# /Users/albertdemskoy/mambaforge/envs/climateProjectEnv/lib/python3.11/site-packages/shapely/constructive.py:181: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/albertdemskoy/mambaforge/envs/climateProjectEnv/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /Users/albertdemskoy/mambaforge/envs/climateProjectEnv/lib/python3.11/site-packages/shapely/constructive.py:181: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/albertdemskoy/mambaforge/envs/climateProjectEnv/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /Users/albertdemskoy/mambaforge/envs/climateProjectEnv/lib/python3.11/site-packages/shapely/constructive.py:181: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/albertdemskoy/mambaforge/envs/climateProjectEnv/lib/python3.11/site-packages/shapely/predicates.py:798: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)

# %%
from utils.SST_utils import get_local_smooth_at_time, sel_mm_yyyyy, get_local_mean, get_cmip_prediction, get_tropical_avg

def filter_nan_from_values(list_obj):
    if len(list_obj) == 0:
        return np.nan
    
    return list_obj[0]

new_cyclones['timestamp'] = pd.to_datetime(new_cyclones['timestamp'])
new_cyclones['timestamp'] = new_cyclones['timestamp'].apply(lambda x: str(x)) 
new_cyclones
# Out:
#                  timestamp   lat    lon BASIN
# index
# 0      2015-01-11 00:00:00 -11.2  100.2    SI
# 1      2015-01-16 00:00:00 -11.0  110.4    SI
# 2      2015-01-18 00:00:00 -12.1  143.3    SP
# 3      2015-01-28 00:00:00 -13.5  119.8    SI
# 4      2015-02-04 00:00:00  -9.9   96.8    SI
# ...                    ...   ...    ...   ...
# 1628   2049-11-15 00:00:00 -12.9   58.0    SI
# 1629   2049-11-28 00:00:00  13.4  130.0    WP
# 1630   2049-12-01 00:00:00  -9.7  117.5    SI
# 1631   2049-12-15 00:00:00  14.0  144.3    WP
# 1632   2049-12-17 00:00:00 -18.2  184.2    SP
#
# [1633 rows x 4 columns]

# %%
## create multi index...

scenarios = [126, 245, 370, 585]
new_cyclones = pd.concat([new_cyclones]*len(scenarios), keys=scenarios, names=['Scenario'], axis=0)
new_cyclones
# Out:
#                           timestamp   lat    lon BASIN
# Scenario index
# 126      0      2015-01-11 00:00:00 -11.2  100.2    SI
#          1      2015-01-16 00:00:00 -11.0  110.4    SI
#          2      2015-01-18 00:00:00 -12.1  143.3    SP
#          3      2015-01-28 00:00:00 -13.5  119.8    SI
#          4      2015-02-04 00:00:00  -9.9   96.8    SI
# ...                             ...   ...    ...   ...
# 585      1628   2049-11-15 00:00:00 -12.9   58.0    SI
#          1629   2049-11-28 00:00:00  13.4  130.0    WP
#          1630   2049-12-01 00:00:00  -9.7  117.5    SI
#          1631   2049-12-15 00:00:00  14.0  144.3    WP
#          1632   2049-12-17 00:00:00 -18.2  184.2    SP
#
# [6532 rows x 4 columns]

# %%
for scenario in scenarios:
    cmip_sst_predictions = get_cmip_prediction(scenario)
    cmip_tropical_avg = get_tropical_avg(cmip_sst_predictions)

    def curried_local_smooth(lat, lon, time):
        return get_local_smooth_at_time(cmip_sst_predictions, lat,lon, time) 

    def curried_local_mean_for_month( lat, lon, time):
        return get_local_mean(cmip_sst_predictions, lat,lon, time) 
    
    def get_tropical_average_for_month(time):
        dt_obj = datetime.strptime(time, '%Y-%m-%d %X')
        month = dt_obj.month
        year = dt_obj.year

        match = cmip_tropical_avg.sel(
            time= sel_mm_yyyyy(cmip_tropical_avg, month, year))

        try:
            return match.mean() 
        except Exception:
            return np.nan
    
    def diff(x1, x2):
        return x1 - x2
        
    
    local_smooth_vectorized = np.vectorize(curried_local_smooth)
    local_mean_for_month_vectorized = np.vectorize(curried_local_mean_for_month)
    tropical_mean_vectorized = np.vectorize(get_tropical_average_for_month)
    diff_vectorized = np.vectorize(diff)

    new_cyclones.loc[scenario,'Tropical SST'] = tropical_mean_vectorized(new_cyclones.loc[scenario,'timestamp'])
    new_cyclones.loc[scenario,'Local SST'] = local_smooth_vectorized(new_cyclones.loc[scenario,'lat'], new_cyclones.loc[scenario,'lon'], new_cyclones.loc[scenario,'timestamp'])
    new_cyclones.loc[scenario,'Relative SST'] =  diff_vectorized(new_cyclones.loc[scenario, 'Local SST'], new_cyclones.loc[scenario,'Tropical SST'])
    # ## for each scenario, positive rSST... This is another interesting thing to check...
  
# new_cyclones = new_cyclones.sort_values(by=['timestamp']).dropna(subset=['Tropical SST', 'Local SST'], how='any')

new_cyclones = new_cyclones.query('`Relative SST` > 0')
new_cyclones
## ONLY HAVE RECORD UP TO 2014
# Out:
#                           timestamp   lat    lon BASIN  Tropical SST  \
# Scenario index
# 126      0      2015-01-11 00:00:00 -11.2  100.2    SI     27.529079
#          1      2015-01-16 00:00:00 -11.0  110.4    SI     27.529079
#          2      2015-01-18 00:00:00 -12.1  143.3    SP     27.529079
#          3      2015-01-28 00:00:00 -13.5  119.8    SI     27.529079
#          4      2015-02-04 00:00:00  -9.9   96.8    SI     27.640711
# ...                             ...   ...    ...   ...           ...
# 585      1626   2049-10-27 00:00:00   5.2  153.1    WP     28.425661
#          1627   2049-11-06 00:00:00  -8.6  135.4    SI     28.619442
#          1629   2049-11-28 00:00:00  13.4  130.0    WP     28.619442
#          1630   2049-12-01 00:00:00  -9.7  117.5    SI     28.649031
#          1631   2049-12-15 00:00:00  14.0  144.3    WP     28.649031
#
#                 Local SST  Relative SST
# Scenario index
# 126      0      28.994474      1.465395
#          1      29.503775      1.974695
#          2      30.122950      2.593870
#          3      30.021164      2.492085
#          4      29.472370      1.831659
# ...                   ...           ...
# 585      1626   30.864584      2.438923
#          1627   29.549793      0.930351
#          1629   29.922213      1.302771
#          1630   31.459743      2.810713
#          1631   28.981529      0.332499
#
# [5991 rows x 7 columns]

# %%
tmp = new_cyclones.reset_index('index', drop=True)
tmp = tmp.set_index(new_cyclones.groupby(level=0).cumcount().rename('cyclone'), append=True)

# %%
tmp.to_csv('../cyclone_data/resampled/future_cyclones_cmip.csv')
